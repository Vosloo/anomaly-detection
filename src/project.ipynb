# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from tensorflow import keras
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    Dense,
    LSTM,
    Dropout,
    TimeDistributed,
    Reshape,
    GlobalMaxPool1D,
    RepeatVector,
)
from tensorflow.keras.preprocessing import sequence
from sklearn.model_selection import train_test_split
import os

plt.rcParams["figure.figsize"] = (12, 8)

os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
# Out:
# 2022-01-26 19:39:26.804924: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-01-26 19:39:26.804940: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# <center><h2> Syntethic Data Generation </h2></center>

# %%
np.random.seed(42)

# %%
n = 50000

# %%
def createRow(n, classes):
    base = np.sin(
        np.linspace((np.random.rand(3)), (np.random.rand(3) + np.array([10, 15, 7])), n)
    )
    if classes[0] > 0:
        base[np.random.randint(0, n), 0] += 2
    if classes[1] > 0:
        base[np.random.randint(0, n), 1] -= 2
    if classes[2] > 0:
        x = np.random.randint(0, n - 5)
        base[x : x + 4, 2] = 0
    if classes[3] > 0:
        x = np.random.randint(0, n - 10)
        base[x : x + 8, 1] += 1.5
    if classes[4] > 0:
        x = np.random.randint(0, n - 7)
        base[x : x + 6, 0] += 1.5
        base[x : x + 6, 2] -= 1.5
    base += np.random.rand(*base.shape) * 0.2
    return base

# %%
xl, yl = [], []
for _ in range(n):
    cl = np.random.rand(5) < 0.25
    xl.append(createRow(np.random.randint(40, 60), cl))
    yl.append(cl)

# %%
np.max([x.shape for x in xl]), np.min([x.shape for x in xl])
# Out:
# (59, 3)

# %%
for i in range(3):
    plt.plot(xl[i])
    print(yl[i])
    plt.show()
# Out:
# [False False False False  True]
# [False False False  True  True]
# [False False False False False]

# %% [markdown]
# <center><h2> Preparing data for training and testing </h2></center>

# %%
X = np.stack(sequence.pad_sequences(xl, dtype="float64", value=0, padding="post", maxlen=60), axis=0)
Y = np.stack(yl, axis=0)

X.shape, Y.shape
# Out:
# ((50000, 60, 3), (50000, 5))

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.15, random_state=88
)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((42500, 60, 3), (7500, 60, 3), (42500, 5), (7500, 5))

# %% [markdown]
# <center><h2> Main model architecture </h2></center>

# %% [markdown]
# We've decided to use a simple neural network model with total of 3 LSTM layers. The first layer (input LSTM) has a size of 64 neurons. After that there is a Droput layer with 0.2 ration and RepeatVector (for creating sub-serieses). After that we've used two additional LSTM layers and a Dropout with 0.4 ratio. Two last layers are Dense one with 64 neurons and tanh as a activation function and our output layer - 5 output size and sigmoid activation.
#
# We've tried many different approaches to layer sizes and activation functions and we've found that the best approach is to use a combination of LSTM and Dense layers below. We've also used Dropout layers with different ratios.
#
# We also found that bigger LSTM layers are worse for our model so we keep the size of the layers to 64.
# Loss function is binary crossentropy and metrics is binary accuracy as those worked best for our model.

# %%
model = Sequential()
model.add(LSTM(64, input_shape=(None, X_train.shape[2])))
model.add(Dropout(0.2))
model.add(RepeatVector(X_train.shape[2]))
model.add(LSTM(64, return_sequences=True))
model.add(LSTM(64))
model.add(Dropout(0.4))
model.add(Dense(64, activation="tanh"))
model.add(Dense(5, activation="sigmoid"))

model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["binary_accuracy"])
# Out:
# 2022-01-26 19:39:31.447838: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-01-26 19:39:31.447870: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: fedora-desktop
# 2022-01-26 19:39:31.447875: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: fedora-desktop
# 2022-01-26 19:39:31.447993: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 495.46.0
# 2022-01-26 19:39:31.448013: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 495.46.0
# 2022-01-26 19:39:31.448018: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 495.46.0
# 2022-01-26 19:39:31.448345: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                17408
#
#  dropout (Dropout)           (None, 64)                0
#
#  repeat_vector (RepeatVector  (None, 3, 64)            0
#  )
#
#  lstm_1 (LSTM)               (None, 3, 64)             33024
#
#  lstm_2 (LSTM)               (None, 64)                33024
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 87,941
# Trainable params: 87,941
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    X_train, y_train, epochs=40, batch_size=32, validation_split=0.2, verbose=1,
    callbacks=[keras.callbacks.EarlyStopping(monitor="val_loss", patience=6)]
)
# Out:
# Epoch 1/40
# 1063/1063 [==============================] - 18s 14ms/step - loss: 0.4689 - binary_accuracy: 0.7938 - val_loss: 0.4539 - val_binary_accuracy: 0.7968
# Epoch 2/40
# 1063/1063 [==============================] - 15s 14ms/step - loss: 0.3856 - binary_accuracy: 0.8313 - val_loss: 0.3645 - val_binary_accuracy: 0.8385
# Epoch 3/40
# 1063/1063 [==============================] - 15s 14ms/step - loss: 0.3372 - binary_accuracy: 0.8540 - val_loss: 0.3280 - val_binary_accuracy: 0.8564
# Epoch 4/40
# 1063/1063 [==============================] - 15s 14ms/step - loss: 0.3170 - binary_accuracy: 0.8634 - val_loss: 0.2917 - val_binary_accuracy: 0.8735
# Epoch 5/40
# 1063/1063 [==============================] - 15s 14ms/step - loss: 0.2907 - binary_accuracy: 0.8752 - val_loss: 0.2858 - val_binary_accuracy: 0.8750
# Epoch 6/40
# 1063/1063 [==============================] - 15s 14ms/step - loss: 0.2717 - binary_accuracy: 0.8815 - val_loss: 0.2427 - val_binary_accuracy: 0.8929
# Epoch 7/40
# 1063/1063 [==============================] - 16s 15ms/step - loss: 0.2348 - binary_accuracy: 0.8987 - val_loss: 0.1900 - val_binary_accuracy: 0.9201
# Epoch 8/40
# 1063/1063 [==============================] - 16s 15ms/step - loss: 0.2028 - binary_accuracy: 0.9142 - val_loss: 0.1773 - val_binary_accuracy: 0.9245
# Epoch 9/40
# 1063/1063 [==============================] - 16s 15ms/step - loss: 0.1771 - binary_accuracy: 0.9252 - val_loss: 0.1959 - val_binary_accuracy: 0.9152
# Epoch 10/40
# 1063/1063 [==============================] - 16s 15ms/step - loss: 0.1660 - binary_accuracy: 0.9295 - val_loss: 0.1507 - val_binary_accuracy: 0.9343
# Epoch 11/40
# 1063/1063 [==============================] - 17s 16ms/step - loss: 0.1669 - binary_accuracy: 0.9295 - val_loss: 0.1651 - val_binary_accuracy: 0.9301
# Epoch 12/40
# 1063/1063 [==============================] - 17s 16ms/step - loss: 0.1591 - binary_accuracy: 0.9316 - val_loss: 0.1421 - val_binary_accuracy: 0.9382
# Epoch 13/40
# 1063/1063 [==============================] - 16s 15ms/step - loss: 0.1582 - binary_accuracy: 0.9325 - val_loss: 0.1441 - val_binary_accuracy: 0.9384
# Epoch 14/40
# 1063/1063 [==============================] - 16s 15ms/step - loss: 0.1528 - binary_accuracy: 0.9347 - val_loss: 0.1391 - val_binary_accuracy: 0.9385
# Epoch 15/40
# 1063/1063 [==============================] - 16s 15ms/step - loss: 0.1452 - binary_accuracy: 0.9374 - val_loss: 0.1346 - val_binary_accuracy: 0.9420
# Epoch 16/40
# 1063/1063 [==============================] - 16s 15ms/step - loss: 0.1410 - binary_accuracy: 0.9406 - val_loss: 0.1340 - val_binary_accuracy: 0.9438
# Epoch 17/40
# 1063/1063 [==============================] - 16s 15ms/step - loss: 0.1345 - binary_accuracy: 0.9434 - val_loss: 0.1237 - val_binary_accuracy: 0.9480
# Epoch 18/40
# 1063/1063 [==============================] - 16s 15ms/step - loss: 0.1304 - binary_accuracy: 0.9469 - val_loss: 0.1100 - val_binary_accuracy: 0.9548
# Epoch 19/40
# 1063/1063 [==============================] - 17s 16ms/step - loss: 0.1220 - binary_accuracy: 0.9504 - val_loss: 0.1012 - val_binary_accuracy: 0.9589
# Epoch 20/40
# 1063/1063 [==============================] - 17s 16ms/step - loss: 0.1157 - binary_accuracy: 0.9538 - val_loss: 0.0975 - val_binary_accuracy: 0.9604
# Epoch 21/40
# 1063/1063 [==============================] - 17s 16ms/step - loss: 0.1121 - binary_accuracy: 0.9567 - val_loss: 0.0968 - val_binary_accuracy: 0.9636
# Epoch 22/40
# 1063/1063 [==============================] - 16s 15ms/step - loss: 0.0958 - binary_accuracy: 0.9626 - val_loss: 0.0795 - val_binary_accuracy: 0.9684
# Epoch 23/40
# 1063/1063 [==============================] - 17s 16ms/step - loss: 0.0869 - binary_accuracy: 0.9661 - val_loss: 0.0758 - val_binary_accuracy: 0.9712
# Epoch 24/40
# 1063/1063 [==============================] - 16s 15ms/step - loss: 0.0806 - binary_accuracy: 0.9684 - val_loss: 0.0670 - val_binary_accuracy: 0.9741
# Epoch 25/40
# 1063/1063 [==============================] - 17s 16ms/step - loss: 0.0893 - binary_accuracy: 0.9661 - val_loss: 0.0884 - val_binary_accuracy: 0.9676
# Epoch 26/40
# 1063/1063 [==============================] - 17s 16ms/step - loss: 0.0747 - binary_accuracy: 0.9710 - val_loss: 0.0637 - val_binary_accuracy: 0.9748
# Epoch 27/40
# 1063/1063 [==============================] - 17s 16ms/step - loss: 0.0654 - binary_accuracy: 0.9742 - val_loss: 0.0558 - val_binary_accuracy: 0.9792
# Epoch 28/40
# 1063/1063 [==============================] - 17s 16ms/step - loss: 0.0664 - binary_accuracy: 0.9749 - val_loss: 0.0559 - val_binary_accuracy: 0.9792
# Epoch 29/40
# 1063/1063 [==============================] - 18s 17ms/step - loss: 0.0634 - binary_accuracy: 0.9751 - val_loss: 0.0487 - val_binary_accuracy: 0.9818
# Epoch 30/40
# 1063/1063 [==============================] - 18s 17ms/step - loss: 0.0584 - binary_accuracy: 0.9778 - val_loss: 0.0448 - val_binary_accuracy: 0.9837
# Epoch 31/40
# 1063/1063 [==============================] - 17s 16ms/step - loss: 0.0528 - binary_accuracy: 0.9800 - val_loss: 0.0457 - val_binary_accuracy: 0.9834
# Epoch 32/40
# 1063/1063 [==============================] - 17s 16ms/step - loss: 0.0532 - binary_accuracy: 0.9807 - val_loss: 0.0431 - val_binary_accuracy: 0.9855
# Epoch 33/40
# 1063/1063 [==============================] - 17s 16ms/step - loss: 0.0592 - binary_accuracy: 0.9791 - val_loss: 0.0423 - val_binary_accuracy: 0.9851
# Epoch 34/40
# 1063/1063 [==============================] - 17s 16ms/step - loss: 0.0478 - binary_accuracy: 0.9830 - val_loss: 0.0498 - val_binary_accuracy: 0.9817
# Epoch 35/40
# 1063/1063 [==============================] - 18s 17ms/step - loss: 0.0449 - binary_accuracy: 0.9837 - val_loss: 0.0342 - val_binary_accuracy: 0.9878
# Epoch 36/40
# 1063/1063 [==============================] - 17s 16ms/step - loss: 0.0444 - binary_accuracy: 0.9845 - val_loss: 0.0460 - val_binary_accuracy: 0.9838
# Epoch 37/40
# 1063/1063 [==============================] - 17s 16ms/step - loss: 0.0406 - binary_accuracy: 0.9859 - val_loss: 0.0343 - val_binary_accuracy: 0.9884
# Epoch 38/40
# 1063/1063 [==============================] - 17s 16ms/step - loss: 0.0372 - binary_accuracy: 0.9871 - val_loss: 0.0265 - val_binary_accuracy: 0.9905
# Epoch 39/40
# 1063/1063 [==============================] - 17s 16ms/step - loss: 0.0342 - binary_accuracy: 0.9879 - val_loss: 0.0305 - val_binary_accuracy: 0.9896
# Epoch 40/40
# 1063/1063 [==============================] - 17s 16ms/step - loss: 0.0418 - binary_accuracy: 0.9866 - val_loss: 0.0323 - val_binary_accuracy: 0.9897

# %%
INTERVAL_WIDTH = 2

explainer = Sequential()
explainer.add(Reshape((-1, INTERVAL_WIDTH, 3), input_shape=(X_train.shape[1], X_train.shape[2])))
explainer.add(TimeDistributed(model))
explainer.add(GlobalMaxPool1D())
explainer.compile("adam", loss="binary_crossentropy", metrics="binary_accuracy")
explainer.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 30, 2, 3)          0
#
#  time_distributed (TimeDistr  (None, 30, 5)            87941
#  ibuted)
#
#  global_max_pooling1d (Globa  (None, 5)                0
#  lMaxPooling1D)
#
# =================================================================
# Total params: 87,941
# Trainable params: 87,941
# Non-trainable params: 0
# _________________________________________________________________

# %%
_ = explainer.fit(
    X_train,
    y_train,
    batch_size=64,
    epochs=30,
    validation_data=(X_test, y_test),
    callbacks=[keras.callbacks.EarlyStopping(monitor="val_loss", patience=5)],
)
# Out:
# Epoch 1/30
# 665/665 [==============================] - 33s 45ms/step - loss: 0.5489 - binary_accuracy: 0.8375 - val_loss: 0.1832 - val_binary_accuracy: 0.9273
# Epoch 2/30
# 665/665 [==============================] - 26s 38ms/step - loss: 0.1726 - binary_accuracy: 0.9313 - val_loss: 0.1473 - val_binary_accuracy: 0.9408
# Epoch 3/30
# 665/665 [==============================] - 27s 41ms/step - loss: 0.1502 - binary_accuracy: 0.9394 - val_loss: 0.1387 - val_binary_accuracy: 0.9427
# Epoch 4/30
# 665/665 [==============================] - 27s 40ms/step - loss: 0.1400 - binary_accuracy: 0.9425 - val_loss: 0.1295 - val_binary_accuracy: 0.9450
# Epoch 5/30
# 665/665 [==============================] - 26s 39ms/step - loss: 0.1339 - binary_accuracy: 0.9441 - val_loss: 0.1298 - val_binary_accuracy: 0.9451
# Epoch 6/30
# 665/665 [==============================] - 26s 39ms/step - loss: 0.1315 - binary_accuracy: 0.9449 - val_loss: 0.1277 - val_binary_accuracy: 0.9453
# Epoch 7/30
# 665/665 [==============================] - 27s 40ms/step - loss: 0.1306 - binary_accuracy: 0.9450 - val_loss: 0.1253 - val_binary_accuracy: 0.9463
# Epoch 8/30
# 665/665 [==============================] - 27s 40ms/step - loss: 0.1285 - binary_accuracy: 0.9458 - val_loss: 0.1262 - val_binary_accuracy: 0.9460
# Epoch 9/30
# 665/665 [==============================] - 27s 40ms/step - loss: 0.1272 - binary_accuracy: 0.9460 - val_loss: 0.1231 - val_binary_accuracy: 0.9462
# Epoch 10/30
# 665/665 [==============================] - 28s 42ms/step - loss: 0.1191 - binary_accuracy: 0.9506 - val_loss: 0.0910 - val_binary_accuracy: 0.9684
# Epoch 11/30
# 665/665 [==============================] - 27s 41ms/step - loss: 0.0799 - binary_accuracy: 0.9724 - val_loss: 0.0599 - val_binary_accuracy: 0.9794
# Epoch 12/30
# 665/665 [==============================] - 28s 42ms/step - loss: 0.0603 - binary_accuracy: 0.9804 - val_loss: 0.0481 - val_binary_accuracy: 0.9838
# Epoch 13/30
# 665/665 [==============================] - 27s 40ms/step - loss: 0.0526 - binary_accuracy: 0.9827 - val_loss: 0.0448 - val_binary_accuracy: 0.9850
# Epoch 14/30
# 665/665 [==============================] - 27s 41ms/step - loss: 0.0490 - binary_accuracy: 0.9840 - val_loss: 0.0372 - val_binary_accuracy: 0.9878
# Epoch 15/30
# 665/665 [==============================] - 27s 41ms/step - loss: 0.0455 - binary_accuracy: 0.9849 - val_loss: 0.0390 - val_binary_accuracy: 0.9872
# Epoch 16/30
# 665/665 [==============================] - 24s 36ms/step - loss: 0.0449 - binary_accuracy: 0.9852 - val_loss: 0.0392 - val_binary_accuracy: 0.9868
# Epoch 17/30
# 665/665 [==============================] - 23s 34ms/step - loss: 0.0438 - binary_accuracy: 0.9854 - val_loss: 0.0399 - val_binary_accuracy: 0.9869
# Epoch 18/30
# 665/665 [==============================] - 28s 42ms/step - loss: 0.0424 - binary_accuracy: 0.9860 - val_loss: 0.0354 - val_binary_accuracy: 0.9878
# Epoch 19/30
# 665/665 [==============================] - 28s 42ms/step - loss: 0.0418 - binary_accuracy: 0.9862 - val_loss: 0.0359 - val_binary_accuracy: 0.9879
# Epoch 20/30
# 665/665 [==============================] - 27s 40ms/step - loss: 0.0420 - binary_accuracy: 0.9861 - val_loss: 0.0358 - val_binary_accuracy: 0.9880
# Epoch 21/30
# 665/665 [==============================] - 27s 40ms/step - loss: 0.0404 - binary_accuracy: 0.9865 - val_loss: 0.0346 - val_binary_accuracy: 0.9881
# Epoch 22/30
# 665/665 [==============================] - 27s 41ms/step - loss: 0.0399 - binary_accuracy: 0.9866 - val_loss: 0.0330 - val_binary_accuracy: 0.9890
# Epoch 23/30
# 665/665 [==============================] - 28s 42ms/step - loss: 0.0396 - binary_accuracy: 0.9869 - val_loss: 0.0365 - val_binary_accuracy: 0.9878
# Epoch 24/30
# 665/665 [==============================] - 28s 41ms/step - loss: 0.0389 - binary_accuracy: 0.9870 - val_loss: 0.0363 - val_binary_accuracy: 0.9879
# Epoch 25/30
# 665/665 [==============================] - 27s 40ms/step - loss: 0.0381 - binary_accuracy: 0.9872 - val_loss: 0.0346 - val_binary_accuracy: 0.9884
# Epoch 26/30
# 665/665 [==============================] - 29s 43ms/step - loss: 0.0381 - binary_accuracy: 0.9872 - val_loss: 0.0340 - val_binary_accuracy: 0.9886
# Epoch 27/30
# 665/665 [==============================] - 27s 41ms/step - loss: 0.0378 - binary_accuracy: 0.9872 - val_loss: 0.0344 - val_binary_accuracy: 0.9889

# %%
anomaly_detector = Model(inputs=explainer.layers[0].input, outputs=explainer.layers[-2].output)
anomaly_detector.compile("adam", loss="binary_crossentropy", metrics="binary_accuracy")
anomaly_detector.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_input (InputLayer)  [(None, 60, 3)]           0
#
#  reshape (Reshape)           (None, 30, 2, 3)          0
#
#  time_distributed (TimeDistr  (None, 30, 5)            87941
#  ibuted)
#
# =================================================================
# Total params: 87,941
# Trainable params: 87,941
# Non-trainable params: 0
# _________________________________________________________________

# %%
anomaly_colors = {
    0: "#edc9af",  # desert sand
    1: "#d3d3d3",  # light gray
    2: "#e6a8d7",  # light orchid
    3: "#fdfd96",  # pastel yellow
    4: "#ff9999",  # salmon pink
}
series_colors = ["#D55E00", "#009E73", "#0072B2"]  # Orange, Green, Blue

patches = []
for k in anomaly_colors.keys():
    patches.append(mpatches.Patch(color=anomaly_colors[k], label=f"Anomaly {k}"))

for ind, scl in enumerate(series_colors):
    patches.append(mpatches.Patch(color=scl, label=f"Series {ind}"))

# %%
counter = 0
for k in np.random.randint(0, X_test.shape[0], 20):
    counter += 1
    for z in range(5):
        predicted = anomaly_detector.predict(X_test[k : k + 1])[0, ..., z]
        plt.gca().set_prop_cycle("color", series_colors)
        plt.plot(X_test[k])
        for i, q in enumerate(predicted):
            if q < 0.5:
                q = 0.01
            plt.axvspan(
                i * INTERVAL_WIDTH,
                i * INTERVAL_WIDTH + INTERVAL_WIDTH,
                color=anomaly_colors[z],
                alpha=q,
            )
    plt.legend(handles=patches)
    plt.show()
